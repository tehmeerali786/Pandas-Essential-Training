# %% [markdown]
# # Basic Analysis

# %%
import pandas as pd

# %%
oo = pd.read_csv('./data/olympics.csv', skiprows=4)
oo.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %% [markdown]
# ## value_counts()

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.Gender.value_counts(ascending=True, dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ## sort_values()

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
oo.sort_values(by=['Edition', 'Athlete'])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo.sort_values(by=['Edition', 'Athlete']).tail(100)
# Out:
#           City  Edition          Sport       Discipline  \
# 28904  Beijing     2008       Softball         Softball
# 28962  Beijing     2008      Taekwondo        Taekwondo
# 27197  Beijing     2008       Aquatics           Diving
# 27183  Beijing     2008       Aquatics           Diving
# 27207  Beijing     2008       Aquatics           Diving
# 28761  Beijing     2008         Rowing           Rowing
# 28905  Beijing     2008       Softball         Softball
# 27945  Beijing     2008  Canoe / Kayak  Canoe / Kayak F
# 27947  Beijing     2008  Canoe / Kayak  Canoe / Kayak F
# 28780  Beijing     2008         Rowing           Rowing
# 28604  Beijing     2008           Judo             Judo
# 28326  Beijing     2008     Gymnastics      Artistic G.
# 28340  Beijing     2008     Gymnastics      Artistic G.
# 27745  Beijing     2008      Badminton        Badminton
# 29156  Beijing     2008      Wrestling  Wrestling Free.
# 28816  Beijing     2008        Sailing          Sailing
# ...

# %% [markdown]
# ## Boolean Indexing

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.Medal == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6         True
# 7        False
# 8        False
# 9         True
# 10       False
# 11       False
# 12       False
# 13        True
# 14       False
# 15        True
# 16       False
# 17       False
# 18        True
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24        True
# 25       False
# 26       False
# 27        True
# 28       False
# 29        True
#          ...
# 29186    False
# 29187     True
# 29188    False
# 29189    False
# 29190    False
# 29191     True
# 29192    False
# 29193    False
# 29194    False
# 29195     True
# 29196    False
# 29197    False
# 29198    False
# 29199     True
# 29200    False
# 29201    False
# 29202    False
# 29203     True
# 29204    False
# 29205    False
# 29206     True
# 29207    False
# 29208    False
# 29209    False
# 29210     True
# 29211    False
# 29212    False
# ...

# %%
oo[oo.Medal == 'Gold']
# Out:
#           City  Edition          Sport       Discipline  \
# 0       Athens     1896       Aquatics         Swimming
# 3       Athens     1896       Aquatics         Swimming
# 6       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 13      Athens     1896      Athletics        Athletics
# 15      Athens     1896      Athletics        Athletics
# 18      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 27      Athens     1896      Athletics        Athletics
# 29      Athens     1896      Athletics        Athletics
# 33      Athens     1896      Athletics        Athletics
# 36      Athens     1896      Athletics        Athletics
# 40      Athens     1896      Athletics        Athletics
# 43      Athens     1896      Athletics        Athletics
# 46      Athens     1896      Athletics        Athletics
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %% [markdown]
# ## String Handling

# %%
oo.Athlete.str.contains('Florence')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 29186    False
# 29187    False
# 29188    False
# 29189    False
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# 29200    False
# 29201    False
# 29202    False
# 29203    False
# 29204    False
# 29205    False
# 29206    False
# 29207    False
# 29208    False
# 29209    False
# 29210    False
# 29211    False
# 29212    False
# ...

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# ## Chanllenge

# %%
oo[oo['Athlete'] == 'OWENS, Jesse'].Event
# Out:
# 6427            100m
# 6439            200m
# 6456    4x100m relay
# 6523       long jump
# Name: Event, dtype: object

# %%
badmintonSingles = oo[(oo.Discipline == 'Badminton') & (oo.Event == 'singles')]

# %%
badmintonSingles.NOC.value_counts()
# Out:
# CHN    13
# INA    10
# DEN     3
# KOR     3
# MAS     2
# NED     1
# Name: NOC, dtype: int64

# %%
type(badmintonSingles)
# Out:
# pandas.core.frame.DataFrame

# %%
CHN = badmintonSingles[badmintonSingles.NOC == 'CHN']

# %%
CHN.sort_values(by=['Athlete'])
# Out:
#             City  Edition      Sport Discipline        Athlete  NOC Gender  \
# 27740    Beijing     2008  Badminton  Badminton      CHEN, Jin  CHN    Men
# 21788    Atlanta     1996  Badminton  Badminton    DONG, Jiong  CHN    Men
# 23720     Sydney     2000  Badminton  Badminton  GONG, Zhichao  CHN  Women
# 20047  Barcelona     1992  Badminton  Badminton     HUANG, Hua  CHN  Women
# 23717     Sydney     2000  Badminton  Badminton    JI, Xinpeng  CHN    Men
# 27741    Beijing     2008  Badminton  Badminton       LIN, Dan  CHN    Men
# 20048  Barcelona     1992  Badminton  Badminton  TANG, Jiuhong  CHN  Women
# 23716     Sydney     2000  Badminton  Badminton    XIA, Xuanze  CHN    Men
# 27745    Beijing     2008  Badminton  Badminton  XIE, Xingfang  CHN  Women
# 23719     Sydney     2000  Badminton  Badminton   YE, Zhaoying  CHN  Women
# 25737     Athens     2004  Badminton  Badminton    ZHANG, Ning  CHN  Women
# ...

# %%
Time = oo[oo.Edition > 1983 ]

# %%
Time.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
Results = oo[(oo.Gender == 'Men') & (oo.Event == '100m freestyle') | (oo.Event == 'sprint') & (oo.Medal == 'Gold')]

# %%
Results.sort_values(by=['Edition'], ascending=False)[['City', 'Edition', 'Athlete', 'NOC']]
# Out:
#               City  Edition                      Athlete  NOC
# 28057      Beijing     2008          PENDLETON, Victoria  GBR
# 27232      Beijing     2008              SULLIVAN, Eamon  AUS
# 27231      Beijing     2008               BERNARD, Alain  FRA
# 27230      Beijing     2008                 LEZAK, Jason  USA
# 27229      Beijing     2008           CIELO FILHO, Cesar  BRA
# 25232       Athens     2004             SCHOEMAN, Roland  RSA
# 25231       Athens     2004   VAN DEN HOOGENBAND, Pieter  NED
# 25230       Athens     2004                  THORPE, Ian  AUS
# 26048       Athens     2004            MUENZER, Lori-Ann  CAN
# 24047       Sydney     2000           BALLANGER, Felicia  FRA
# 23217       Sydney     2000             POPOV, Alexander  RUS
# 23216       Sydney     2000   VAN DEN HOOGENBAND, Pieter  NED
# 23215       Sydney     2000               HALL, Gary Jr.  USA
# 22084      Atlanta     1996           BALLANGER, Felicia  FRA
# ...

# %%
type(Results)
# Out:
# pandas.core.frame.DataFrame

# %%
Results.City.value_counts()
# Out:
# Athens                   6
# Los Angeles              6
# London                   6
# Beijing                  5
# Seoul                    4
# Atlanta                  4
# Barcelona                4
# Sydney                   4
# Paris                    3
# Mexico                   3
# Helsinki                 3
# Montreal                 3
# Tokyo                    3
# Munich                   3
# Berlin                   3
# Amsterdam                3
# Rome                     3
# St Louis                 3
# Moscow                   3
# Stockholm                3
# Antwerp                  3
# Melbourne / Stockholm    3
# Name: City, dtype: int64
